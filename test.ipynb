# %%
import sys

# %%
sys.path.append(r"/home/gpaul/Scripts/Maru.Materials/src")

# %%
import materials

# %%
borosilicate = materials.Borosilicate_glass()

# %%
borosilicate.thermalconductivity()[0].head()
# Out:
#        T(K)  lambda(W/mK)
# 0  0.080682      0.000122
# 1  0.092242      0.000164
# 2  0.102364      0.000204
# 3  0.117015      0.000258
# 4  0.133772      0.000336

# %%
borosilicate.thermalconductivity()[1].head()
# Out:
#        T(K)  lambda(W/mK)
# 0  0.039650      0.000030
# 1  0.060881      0.000067
# 2  0.090908      0.000156
# 3  0.147517      0.000402
# 4  0.194516      0.000702

# %%
borosilicate.cte().head()
# Out:
#        T(K)  CTE(1/K)
# 0  3.969539 -0.000015
# 1  5.812121 -0.000015
# 2  7.218021 -0.000016
# 3  8.097241 -0.000016
# 4  8.888060 -0.000017

# %%
fusedsilica = materials.Fusedsilica_glass()

# %%
fusedsilica.thermalconductivity()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 fusedsilica.thermalconductivity()
#
# File ~/Scripts/Maru.Materials/src/materials/MaruMaterials.py:33, in Fusedsilica_glass.thermalconductivity(self)
#      31 def thermalconductivity(self):
#      32     units=["T(K)","lambda(W/mK)"]
# ---> 33     k1=self._load_property(units,"src/materials/database/fusedsilica_lambda_White1997.csv")
#      34     return k1
#
# File ~/Scripts/Maru.Materials/src/materials/base.py:14, in Material._load_property(self, units, filename)
#      10 def _load_property(self, units, filename):
#      12     path = Path(__file__).parent / "database" / filename
# ---> 14     df = pd.read_csv(path,
#      15                         sep=";",
#      16                         decimal=",",
#      17                         header=None,
#      18                         names=units)
# ...
